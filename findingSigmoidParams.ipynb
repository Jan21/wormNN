# %%
# %matplotlib inline
import numpy as np
import math
import matplotlib.pyplot as plt
vrest=-0.07
length=100


inp=np.linspace(vrest,0,length)

v=np.zeros(length)
def sigmoid(x,sigma,mu):
    return (1/(1+math.exp(-sigma*(x-mu))))
x=1.2
y=0
a=0.000001
b=0.99
print 'b='+str(b)
inner=(1-b)/b
inner2=(1-a)/(a*(1-b)/b)

mu=-vrest*(math.log(inner)/math.log(inner2))
sigma=math.log((1-b)/b)/mu
print 'aval=',sigmoid(a,sigma,mu)
print 'bval=',sigmoid(b,sigma,mu)
print "sigma:",sigma
print "mu:",mu
for i in range(length):
    v[i]=sigmoid(inp[i],sigma,mu)
plt.plot(inp,v)
plt.show()
# Out:
# b=0.99
# aval= 0.990002603453
# bval= 1.0
# sigma: 263.008991544
# mu: -0.0174713412768

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
import matplotlib

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
p0=np.linspace(1,2,5)
p1=np.linspace(1,2,5)
p2=np.linspace(1,2,5)
resultsOfSim=np.random.random([5,5,5])
minim=np.min(resultsOfSim)
maxim=np.max(resultsOfSim)
colormap = plt.cm.bwr  # or any other colormap
normalize = matplotlib.colors.Normalize(vmin=minim, vmax=maxim)
rgb = plt.get_cmap('jet')(resultsOfSim)
ax.scatter(p0, p1, p2, c=rgb)

ax.set_xlabel(params[0])
ax.set_ylabel(params[1])
ax.set_zlabel(params[2])
plt.show()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-8-6184567b7e5f> in <module>()
#      17 normalize = matplotlib.colors.Normalize(vmin=minim, vmax=maxim)
#      18 rgb = plt.get_cmap('jet')(resultsOfSim)
# ---> 19 ax.scatter(p0, p1, p2, c=rgb)
#      20
#      21 ax.set_xlabel(params[0])
#
# C:\Users\hulova\AppData\Local\conda\conda\envs\bmnn\lib\site-packages\mpl_toolkits\mplot3d\axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2350             xs, ys, zs, s = cbook.delete_masked_points(xs, ys, zs, s)
#    2351
# -> 2352         patches = Axes.scatter(self, xs, ys, s=s, c=c, *args, **kwargs)
#    2353         if not cbook.iterable(zs):
#    2354             is_2d = True
#
# C:\Users\hulova\AppData\Local\conda\conda\envs\bmnn\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...
